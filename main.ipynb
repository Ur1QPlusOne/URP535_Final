# %% [markdown]
# # Setup

# %%
import geopandas as gpd
import pandas as pd
import mapclassify
from matplotlib import pyplot as plt
import requests
import streamlit as st

# %% [markdown]
# # Read in data

# %%
def read_api(url):
    # Requests to pull the data
    response = requests.get(url)
    # If the request is accepted then...
    print(response.status_code)
    if response.status_code == 200:
        # Read in the data as a json file
        data = response.json()
        # Convert the json file into a GeoDataFrame (dataframe containing geometry)
        return gpd.GeoDataFrame(data)
    else:
        return None

# Read in permit data of completed new-build projects
newbuild_df = read_api("https://data.cityofchicago.org/resource/ydr8-5enu.json?permit_status=COMPLETE&permit_type=PERMIT - NEW CONSTRUCTION&$limit=50000")
# Read in permit data of completed retrofit projects
retrofit_df = read_api("https://data.cityofchicago.org/resource/ydr8-5enu.json?permit_status=COMPLETE&permit_type=PERMIT - RENOVATION/ALTERATION&$limit=50000")
# Read in energy benchmark data of all buildings
energy_df = read_api("https://data.cityofchicago.org/resource/xq83-jr8c.json?$limit=50000")
# Out:
# 200
# 200
# 200

# %% [markdown]
# # Data cleaning

# %%
necessary_columns = [x for x in retrofit_df.columns if x.startswith('contact') == False]

retrofit_df = retrofit_df[necessary_columns]
newbuild_df = newbuild_df[necessary_columns]

# %%
display(energy_df.head())
print(energy_df.groupby('reporting_status')['reporting_status'].count())
print(energy_df.groupby('community_area')['community_area'].count().sort_values())
print(display(energy_df.groupby('data_year')['data_year'].count()))
# Out:
#   data_year      id reporting_status                    address zip_code  \
# 0      2021  101671    Not Submitted     6101 6115 N SEELEY AVE    60659
# 1      2021  101826    Not Submitted     8136 8142 S DREXEL AVE    60619
# 2      2021  102323    Not Submitted  3515 3525 W FRANKLIN BLVD    60624
# 3      2022  256888   Submitted Data         318 N CARPENTER ST    60607
# 4      2021  104374    Not Submitted        6000  N SHERIDAN RD    60660
#
#   chicago_energy_rating exempt_from_chicago_energy_rating community_area  \
# 0                     0                             False     WEST RIDGE
# 1                     0                             False        CHATHAM
# 2                     0                             False  HUMBOLDT PARK
# 3                     4                             False            NaN
# 4                     0                             False      EDGEWATER
#
#   gross_floor_area_buildings_sq_ft           latitude  ...  \
# 0                            65250        41.99046172  ...
# 1                            66888        41.74401302  ...
# 2                            93000         41.8808242  ...
# 3                           104849  41.88736471232649  ...
# 4                            55686        41.99090057  ...
#
#   district_steam_use_kbtu district_chilled_water_use_kbtu site_eui_kbtu_sq_ft  \
# 0                     NaN                             NaN                 NaN
# 1                     NaN                             NaN                 NaN
# 2                     NaN                             NaN                 NaN
# 3                       0                               0                32.4
# 4                     NaN                             NaN                 NaN
#
#   source_eui_kbtu_sq_ft weather_normalized_site_eui_kbtu_sq_ft  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                  61.9                                   32.8
# 4                   NaN                                    NaN
#
#   weather_normalized_source_eui_kbtu_sq_ft  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     61.4
# 4                                      NaN
#
#   total_ghg_emissions_metric_tons_co2e ghg_intensity_kg_co2e_sq_ft  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                311.5                           3
# 4                                  NaN                         NaN
#
#   water_use_kgal all_other_fuel_use_kbtu
# 0            NaN                     NaN
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
#
# [5 rows x 35 columns]
# reporting_status
# Exempt                957
# Not Covered 2024      312
# Not Submitted        3867
# Submitted           17572
# Submitted Data       5621
# Name: reporting_status, dtype: int64
# community_area
# outside Chicago, in Bedford Park       1
# Edison Park                            2
# Burnside                               2
# Beverly                                2
# Lakeview                               3
#                                     ...
# LINCOLN PARK                         990
# LAKE VIEW                           1274
# NEAR WEST SIDE                      1821
# LOOP                                2670
# NEAR NORTH SIDE                     3746
# Name: community_area, Length: 157, dtype: int64
# data_year
# 2014     243
# 2015    1521
# 2016    2717
# 2017    2797
# 2018    3430
# 2019    3438
# 2020    3582
# 2021    3550
# 2022    3613
# 2023    3438
# Name: data_year, dtype: int64
# None

# %%
newbuild_gdf = gpd.GeoDataFrame(newbuild_df)
retrofit_gdf = gpd.GeoDataFrame(retrofit_df)
energy_gdf = gpd.GeoDataFrame(energy_df)

# %% [markdown]
# # Dataviz

# %%
# Optional: Filter by year
#selected_year = st.slider("Select Year", int(energy_gdf['data_year'].min()), int(energy_gdf['data_year'].max()), step=1)
selected_year = 2023
df_map = energy_gdf[energy_gdf['data_year'] == selected_year]

st.map(df_map[['latitude', 'longitude']])

# Optional: Add extra info
st.write("Showing buildings for:", selected_year)
st.dataframe(df_map[['address', 'community_area']])
# Out:
# 2025-04-10 16:27:52.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:52.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:52.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:53.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:53.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:53.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:54.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-10 16:27:54.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
energy_df.columns
# Out:
# Index(['data_year', 'id', 'reporting_status', 'address', 'zip_code',
#        'chicago_energy_rating', 'exempt_from_chicago_energy_rating',
#        'community_area', 'gross_floor_area_buildings_sq_ft', 'latitude',
#        'longitude', 'location', 'row_id', ':@computed_region_43wa_7qmu',
#        ':@computed_region_vrxf_vc4k', ':@computed_region_6mkv_f3dw',
#        ':@computed_region_bdys_3d7i', ':@computed_region_awaf_s7ux',
#        'property_name', 'primary_property_type', 'year_built', 'of_buildings',
#        'energy_star_score', 'electricity_use_kbtu', 'natural_gas_use_kbtu',
#        'district_steam_use_kbtu', 'district_chilled_water_use_kbtu',
#        'site_eui_kbtu_sq_ft', 'source_eui_kbtu_sq_ft',
#        'weather_normalized_site_eui_kbtu_sq_ft',
#        'weather_normalized_source_eui_kbtu_sq_ft',
#        'total_ghg_emissions_metric_tons_co2e', 'ghg_intensity_kg_co2e_sq_ft',
#        'water_use_kgal', 'all_other_fuel_use_kbtu'],
#       dtype='object')

# %%
energy_df[['data_year','id','address','chicago_energy_rating','longitude','latitude','energy_star_score','electricity_use_kbtu','site_eui_kbtu_sq_ft']].head()
# Out:
#   data_year      id                    address chicago_energy_rating  \
# 0      2021  101671     6101 6115 N SEELEY AVE                     0
# 1      2021  101826     8136 8142 S DREXEL AVE                     0
# 2      2021  102323  3515 3525 W FRANKLIN BLVD                     0
# 3      2022  256888         318 N CARPENTER ST                     4
# 4      2021  104374        6000  N SHERIDAN RD                     0
#
#           longitude           latitude energy_star_score electricity_use_kbtu  \
# 0      -87.70620782        41.99046172               NaN                  NaN
# 1      -87.60549928        41.74401302               NaN                  NaN
# 2      -87.72327934         41.8808242               NaN                  NaN
# 3  -87.653505317143  41.88736471232649                98            1669219.6
# 4      -87.66660744        41.99090057               NaN                  NaN
#
#   site_eui_kbtu_sq_ft
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                32.4
# 4                 NaN

# %%
energy_df[['data_year','id','address','chicago_energy_rating','longitude','latitude','energy_star_score']].head()
energy_df_clean = energy_df.dropna(subset=['data_year', 'longitude', 'latitude'])
energy_df_clean
# Out:
#       data_year      id  reporting_status                    address zip_code  \
# 0          2021  101671     Not Submitted     6101 6115 N SEELEY AVE    60659
# 1          2021  101826     Not Submitted     8136 8142 S DREXEL AVE    60619
# 2          2021  102323     Not Submitted  3515 3525 W FRANKLIN BLVD    60624
# 3          2022  256888    Submitted Data         318 N CARPENTER ST    60607
# 4          2021  104374     Not Submitted        6000  N SHERIDAN RD    60660
# ...         ...     ...               ...                        ...      ...
# 28324      2023  101753         Submitted  222 South Riverside Plaza    60606
# 28325      2023  175987         Submitted     11840 S Marshfield Ave    60643
# 28326      2023  250083         Submitted         1930 W. Loyola Ave    60626
# 28327      2023  256672         Submitted  2903-2923 N Claremont Ave    60618
# 28328      2023  100397  Not Covered 2024             3939 W 79th St    60652
#
#       chicago_energy_rating exempt_from_chicago_energy_rating  community_area  \
# 0                         0                             False      WEST RIDGE
# 1                         0                             False         CHATHAM
# 2                         0                             False   HUMBOLDT PARK
# 3                         4                             False             NaN
# 4                         0                             False       EDGEWATER
# ...                     ...                               ...             ...
# 28324                     4                               NaN  Near West Side
# 28325                   2.5                               NaN     Morgan Park
# 28326                   2.5                               NaN      West Ridge
# 28327                     3                               NaN        Avondale
# 28328                   NaN                              True         Ashburn
#
#       gross_floor_area_buildings_sq_ft           latitude  ...  \
# 0                                65250        41.99046172  ...
# 1                                66888        41.74401302  ...
# 2                                93000         41.8808242  ...
# 3                               104849  41.88736471232649  ...
# 4                                55686        41.99090057  ...
# ...                                ...                ...  ...
# 28324                          1237455          41.874634  ...
# 28325                           129029          41.973128  ...
# 28326                            99530          41.893483  ...
# 28327                            71737          41.901711  ...
# 28328                              NaN          41.748760  ...
#
#       district_steam_use_kbtu district_chilled_water_use_kbtu  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                           0                               0
# 4                         NaN                             NaN
# ...                       ...                             ...
# 28324                     NaN                             NaN
# 28325                     NaN                             NaN
# 28326                     NaN                             NaN
# 28327                     NaN                             NaN
# 28328                     NaN                             NaN
#
#       site_eui_kbtu_sq_ft source_eui_kbtu_sq_ft  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                    32.4                  61.9
# 4                     NaN                   NaN
# ...                   ...                   ...
# 28324                56.1                 111.8
# 28325                64.1                 126.8
# 28326               105.4                 151.3
# 28327                77.8                 112.1
# 28328                 NaN                   NaN
#
#       weather_normalized_site_eui_kbtu_sq_ft  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                       32.8
# 4                                        NaN
# ...                                      ...
# 28324                                   60.1
# 28325                                   65.6
# 28326                                  117.5
# 28327                                   85.2
# 28328                                    NaN
#
#       weather_normalized_source_eui_kbtu_sq_ft  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                         61.4
# 4                                          NaN
# ...                                        ...
# 28324                                      116
# 28325                                      131
# 28326                                    163.2
# 28327                                    121.4
# 28328                                      NaN
#
#       total_ghg_emissions_metric_tons_co2e ghg_intensity_kg_co2e_sq_ft  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                    311.5                           3
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 28324                               6936.2                         5.6
# 28325                                820.2                         6.4
# 28326                                757.9                         7.6
# 28327                                404.7                         5.6
# 28328                                  NaN                         NaN
#
#       water_use_kgal all_other_fuel_use_kbtu
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# ...              ...                     ...
# 28324        19287.4                     NaN
# 28325            NaN                     NaN
# 28326            NaN                     NaN
# 28327            NaN                     NaN
# 28328            NaN                     NaN
#
# [28314 rows x 35 columns]

# %%
retrofit_df.columns
retrofit_df[['community_area','ward','street_number','street_name','census_tract']].head()
# Out:
#   community_area ward street_number        street_name census_tract
# 0             27   24           739  INDEPENDENCE BLVD       270500
# 1             28   27          1628    WASHINGTON BLVD       280400
# 2             10   41          6414    NEW ENGLAND AVE       100200
# 3              8   42           321           CLARK ST        81700
# 4              9   41          7356         HARLEM AVE        90100

# %%
energy_df_clean = energy_df.dropna(subset=['data_year', 'longitude', 'latitude', 'energy_star_score'])
# Make columns numbers
energy_df_clean['data_year'] = pd.to_numeric(energy_df_clean['data_year'], errors='coerce')
energy_df_clean['longitude'] = pd.to_numeric(energy_df_clean['longitude'], errors='coerce')
energy_df_clean['latitude'] = pd.to_numeric(energy_df_clean['latitude'], errors='coerce')
# Filter out non-chicago locations
energy_df_clean = energy_df_clean[(energy_df_clean['latitude'].between(41.60, 42.10)) & (energy_df_clean['longitude'].between(-88.00, -87.50))]



energy_df_clean.head()
# Out:
# /var/folders/m6/k51w_3q94hn6j_yy3x_2g81m0000gn/T/ipykernel_60075/2359007054.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df_clean['data_year'] = pd.to_numeric(energy_df_clean['data_year'], errors='coerce')
# /var/folders/m6/k51w_3q94hn6j_yy3x_2g81m0000gn/T/ipykernel_60075/2359007054.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df_clean['longitude'] = pd.to_numeric(energy_df_clean['longitude'], errors='coerce')
# /var/folders/m6/k51w_3q94hn6j_yy3x_2g81m0000gn/T/ipykernel_60075/2359007054.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df_clean['latitude'] = pd.to_numeric(energy_df_clean['latitude'], errors='coerce')
#     data_year      id reporting_status             address zip_code  \
# 3        2022  256888   Submitted Data  318 N CARPENTER ST    60607
# 18       2022  256882   Submitted Data  1648 W DIVISION ST    60622
# 24       2022  160184   Submitted Data     29 E Madison St    60602
# 33       2021  260184        Submitted   2728 N HAMPDEN CT    60614
# 36       2021  260149        Submitted  3145 S Ashland Ave    60608
#
#    chicago_energy_rating exempt_from_chicago_energy_rating community_area  \
# 3                      4                             False            NaN
# 18                   1.5                             False            NaN
# 24                   2.5                             False           LOOP
# 33                   1.5                             False   LINCOLN PARK
# 36                     4                             False  MCKINLEY PARK
#
#    gross_floor_area_buildings_sq_ft   latitude  ...  district_steam_use_kbtu  \
# 3                            104849  41.887365  ...                        0
# 18                           106888  41.903424  ...                        0
# 24                           240076  41.881965  ...                        0
# 33                           170000  41.922011  ...                        0
# 36                            74495  41.836579  ...                        0
#
#    district_chilled_water_use_kbtu site_eui_kbtu_sq_ft source_eui_kbtu_sq_ft  \
# 3                                0                32.4                  61.9
# 18                               0                 105                 138.1
# 24                               0                 117                 203.5
# 33                               0               117.6                 161.6
# 36                               0               176.5                 373.7
#
#    weather_normalized_site_eui_kbtu_sq_ft  \
# 3                                    32.8
# 18                                  108.6
# 24                                  122.7
# 33                                  115.5
# 36                                  176.5
#
#    weather_normalized_source_eui_kbtu_sq_ft  \
# 3                                      61.4
# 18                                    139.8
# 24                                    209.4
# 33                                    159.4
# 36                                    373.7
#
#    total_ghg_emissions_metric_tons_co2e ghg_intensity_kg_co2e_sq_ft  \
# 3                                 311.5                           3
# 18                                638.8                           7
# 24                               2361.5                         9.8
# 33                               1148.3                         8.2
# 36                               1417.8                          19
#
#    water_use_kgal all_other_fuel_use_kbtu
# 3             NaN                     NaN
# 18            NaN                     NaN
# 24            NaN                     NaN
# 33            NaN                     NaN
# 36            NaN                     NaN
#
# [5 rows x 35 columns]

# %%
energy_df_clean.columns
# Out:
# Index(['data_year', 'id', 'reporting_status', 'address', 'zip_code',
#        'chicago_energy_rating', 'exempt_from_chicago_energy_rating',
#        'community_area', 'gross_floor_area_buildings_sq_ft', 'latitude',
#        'longitude', 'location', 'row_id', ':@computed_region_43wa_7qmu',
#        ':@computed_region_vrxf_vc4k', ':@computed_region_6mkv_f3dw',
#        ':@computed_region_bdys_3d7i', ':@computed_region_awaf_s7ux',
#        'property_name', 'primary_property_type', 'year_built', 'of_buildings',
#        'energy_star_score', 'electricity_use_kbtu', 'natural_gas_use_kbtu',
#        'district_steam_use_kbtu', 'district_chilled_water_use_kbtu',
#        'site_eui_kbtu_sq_ft', 'source_eui_kbtu_sq_ft',
#        'weather_normalized_site_eui_kbtu_sq_ft',
#        'weather_normalized_source_eui_kbtu_sq_ft',
#        'total_ghg_emissions_metric_tons_co2e', 'ghg_intensity_kg_co2e_sq_ft',
#        'water_use_kgal', 'all_other_fuel_use_kbtu'],
#       dtype='object')

# %%
energy_df_clean.head()
energy_df_clean = energy_df.dropna(subset=['data_year', 'longitude', 'latitude', 'energy_star_score'])
energy_df_clean['chicago_energy_rating'] = pd.to_numeric(energy_df_clean['chicago_energy_rating'], errors='coerce')


energy_grouped_comm = energy_df_clean.groupby('community_area').agg({
    "chicago_energy_rating": "sum",
    "address": "count",
}).reset_index()
energy_grouped_comm.columns = ["Community_Area", "Total_Energy_Rating", "Total_Buildings"]
energy_grouped_comm['Mean_Rating'] = energy_grouped_comm.apply(lambda x: x["Total_Energy_Rating"]/x["Total_Buildings"], axis=1)

display(energy_grouped_comm.sort_values("Total_Buildings"))
# Out:
# /var/folders/m6/k51w_3q94hn6j_yy3x_2g81m0000gn/T/ipykernel_60075/4265988090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   energy_df_clean['chicago_energy_rating'] = pd.to_numeric(energy_df_clean['chicago_energy_rating'], errors='coerce')
#                        Community_Area  Total_Energy_Rating  Total_Buildings  \
# 155  outside Chicago, in Bedford Park                  3.0                1
# 122                         Riverdale                  1.0                1
# 50                        Fuller Park                  3.0                1
# 90                      Mckinley Park                  3.5                1
# 149                West Garfield Park                  3.5                2
# ..                                ...                  ...              ...
# 102                   Near North Side               1600.5              612
# 73                          LAKE VIEW               2243.0             1072
# 96                     NEAR WEST SIDE               2904.5             1410
# 77                               LOOP               3631.5             2046
# 94                    NEAR NORTH SIDE               5286.0             2969
#
#      Mean_Rating
# 155     3.000000
# 122     1.000000
# 50      3.000000
# 90      3.500000
# 149     1.750000
# ..           ...
# 102     2.615196
# 73      2.092351
# 96      2.059929
# 77      1.774927
# 94      1.780397
#
# [156 rows x 4 columns]

# %%
retrofit_df[['street_number','street_name']].head()
retrofit_df.columns
# Out:
# Index(['id', 'permit_', 'permit_status', 'permit_milestone', 'permit_type',
#        'review_type', 'application_start_date', 'issue_date',
#        'processing_time', 'street_number', 'street_direction', 'street_name',
#        'work_description', 'building_fee_paid', 'zoning_fee_paid',
#        'other_fee_paid', 'subtotal_paid', 'building_fee_unpaid',
#        'zoning_fee_unpaid', 'other_fee_unpaid', 'subtotal_unpaid',
#        'building_fee_waived', 'building_fee_subtotal', 'zoning_fee_subtotal',
#        'other_fee_subtotal', 'zoning_fee_waived', 'other_fee_waived',
#        'subtotal_waived', 'total_fee', 'reported_cost', 'pin_list',
#        'community_area', 'census_tract', 'ward', 'xcoordinate', 'ycoordinate',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
allhomes_df = result_vertical = pd.concat([retrofit_df, newbuild_df])
allhomes_df = allhomes_df[['id','permit_type','community_area','ward','latitude','longitude','location']]
allhomes_df.head()
# Out:
#         id                     permit_type community_area ward  \
# 0  3316806  PERMIT - RENOVATION/ALTERATION             27   24
# 1  3362770  PERMIT - RENOVATION/ALTERATION             28   27
# 2  3368303  PERMIT - RENOVATION/ALTERATION             10   41
# 3  3373499  PERMIT - RENOVATION/ALTERATION              8   42
# 4  3378148  PERMIT - RENOVATION/ALTERATION              9   41
#
#             latitude           longitude  \
# 0  41.87153852754136  -87.71955488514301
# 1  41.88338943530201  -87.66807949279023
# 2  41.99913120190079   -87.7983587609477
# 3  41.88787484815479  -87.63088485124779
# 4  42.01519122083687    -87.806741706282
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [-87.71955488...
# 1  {'type': 'Point', 'coordinates': [-87.66807949...
# 2  {'type': 'Point', 'coordinates': [-87.79835876...
# 3  {'type': 'Point', 'coordinates': [-87.63088485...
# 4  {'type': 'Point', 'coordinates': [-87.80674170...

# %%
""" WARD ZIPCODE ZONING CODE SETUP """
zipcodes_df = read_api("https://data.cityofchicago.org/resource/unjd-c2ca.json")
zipcodes_df.head()
# Out:
# 200
#                                             the_geom objectid    zip  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       33  60647
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       34  60639
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       35  60707
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       36  60622
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       37  60651
#
#       shape_area      shape_len
# 0  106052287.488  42720.0444058
# 1  127476050.762  48103.7827213
# 2  45069038.4783  27288.6096123
# 3  70853834.3797  42527.9896789
# 4  99039621.2518  47970.1401531

# %%
""" WARD ZIPCODE ZONING CODE SETUP """
wards_df = read_api("https://data.cityofchicago.org/resource/p293-wvbd.json")
wards_df.head()
# Out:
# 200
#   ward                                           the_geom objectid  \
# 0    1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       51
# 1    2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       52
# 2    3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       53
# 3    4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       54
# 4    5  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       55
#
#                  edit_date ward_id                                globalid  \
# 0  2022-06-01T00:00:00.000       1  {DB2A2A7D-FAF1-42A4-B061-AE18C31A80BB}
# 1  2022-06-01T00:00:00.000       2  {88F300F6-D6DF-4337-8DE3-0C2D27A5B338}
# 2  2022-06-01T00:00:00.000       3  {4F169974-0F93-4C35-98C1-20A8415C72F5}
# 3  2022-06-01T00:00:00.000       4  {02DC7BBB-BD1E-413C-994E-0A3154FD3D54}
# 4  2022-06-01T00:00:00.000       5  {0A109A41-9DED-47D7-934E-1EA1CC7EE025}
#
#       st_area_sh     st_length_
# 0  65893461.4401  61878.8215865
# 1  31285111.9943  74175.9492394
# 2  97773414.0062  85625.5976201
# 3  115809136.712  103594.867171
# 4  112080253.112  88207.6902413

# %%
communities_gdf = gpd.read_file('/Users/dinguid/PH Accelerator Dropbox/Dylan Ingui/Mac/Desktop/_Urban Technology/URP535 - Urban Informatics/URP535_Final/CommAreas_20250407.csv')
communities_gdf = communities_gdf[['the_geom','AREA_NUMBE','COMMUNITY','SHAPE_AREA']]
communities_gdf.head()
# Out:
#                                             the_geom AREA_NUMBE  \
# 0  MULTIPOLYGON (((-87.60914087617894 41.84469250...         35
# 1  MULTIPOLYGON (((-87.59215283879394 41.81692934...         36
# 2  MULTIPOLYGON (((-87.62879823733725 41.80189303...         37
# 3  MULTIPOLYGON (((-87.6067081256125 41.816813770...         38
# 4  MULTIPOLYGON (((-87.59215283879394 41.81692934...         39
#
#          COMMUNITY     SHAPE_AREA
# 0          DOUGLAS  46004621.1581
# 1          OAKLAND  16913961.0408
# 2      FULLER PARK  19916704.8692
# 3  GRAND BOULEVARD  48492503.1554
# 4          KENWOOD  29071741.9283

# %%
import geopandas as gpd

# Step 1: Convert allhomes_df to a GeoDataFrame
allhomes_gdf = gpd.GeoDataFrame(
    allhomes_df,
    geometry=gpd.points_from_xy(allhomes_df['longitude'], allhomes_df['latitude']),
    crs="EPSG:4326"
)

# Step 2: Convert communities_df to a GeoDataFrame (skip wkt.loads step)
communities_gdf = gpd.GeoDataFrame(
    communities_gdf,
    geometry='the_geom',
    crs="EPSG:4326"
)

# Step 3: Spatial join to assign each home to a community
homes_with_community = gpd.sjoin(allhomes_gdf, communities_gdf, how='left', predicate='within')

# Step 4: Group by community area number and count permits
permit_counts = homes_with_community.groupby('AREA_NUMBE').size().reset_index(name='permit_count')

# Step 5: Merge permit counts into community_gdf
community_with_permits = communities_gdf.merge(permit_counts, on='AREA_NUMBE', how='left')
community_with_permits
# Out:
#                                              the_geom AREA_NUMBE  \
# 0   MULTIPOLYGON (((-87.60914 41.84469, -87.60915 ...         35
# 1   MULTIPOLYGON (((-87.59215 41.81693, -87.59231 ...         36
# 2   MULTIPOLYGON (((-87.6288 41.80189, -87.62879 4...         37
# 3   MULTIPOLYGON (((-87.60671 41.81681, -87.6067 4...         38
# 4   MULTIPOLYGON (((-87.59215 41.81693, -87.59215 ...         39
# ..                                                ...        ...
# 72  MULTIPOLYGON (((-87.69646 41.70714, -87.69644 ...         74
# 73  MULTIPOLYGON (((-87.64215 41.68508, -87.64249 ...         75
# 74  MULTIPOLYGON (((-87.83658 41.9864, -87.83658 4...         76
# 75  MULTIPOLYGON (((-87.65456 41.99817, -87.65456 ...         77
# 76  MULTIPOLYGON (((-87.80676 42.00084, -87.80676 ...          9
#
#           COMMUNITY     SHAPE_AREA  permit_count
# 0           DOUGLAS  46004621.1581           424
# 1           OAKLAND  16913961.0408           189
# 2       FULLER PARK  19916704.8692           111
# 3   GRAND BOULEVARD  48492503.1554          1074
# 4           KENWOOD  29071741.9283           347
# ..              ...            ...           ...
# 72  MOUNT GREENWOOD  75584290.0209           441
# 73      MORGAN PARK  91877340.6988           358
# 74            OHARE  371835607.687           244
# 75        EDGEWATER  48449990.8397          1063
# 76      EDISON PARK  31636313.7864           301
#
# [77 rows x 5 columns]

# %%
homes_with_community
# Out:
#             id                     permit_type community_area ward  \
# 0      3316806  PERMIT - RENOVATION/ALTERATION             27   24
# 1      3362770  PERMIT - RENOVATION/ALTERATION             28   27
# 2      3368303  PERMIT - RENOVATION/ALTERATION             10   41
# 3      3373499  PERMIT - RENOVATION/ALTERATION              8   42
# 4      3378148  PERMIT - RENOVATION/ALTERATION              9   41
# ...        ...                             ...            ...  ...
# 25249  3390382       PERMIT - NEW CONSTRUCTION             27   24
# 25250  3391773       PERMIT - NEW CONSTRUCTION             71   17
# 25251  3394840       PERMIT - NEW CONSTRUCTION             27   24
# 25252  3043824       PERMIT - NEW CONSTRUCTION             15   45
# 25253  3395700       PERMIT - NEW CONSTRUCTION             56   23
#
#                  latitude           longitude  \
# 0       41.87153852754136  -87.71955488514301
# 1       41.88338943530201  -87.66807949279023
# 2       41.99913120190079   -87.7983587609477
# 3       41.88787484815479  -87.63088485124779
# 4       42.01519122083687    -87.806741706282
# ...                   ...                 ...
# 25249  41.872655795152845  -87.70721421915886
# 25250  41.750729510516344  -87.64557103359442
# 25251   41.87265270488431  -87.70751585933291
# 25252  41.952510622379016  -87.75317109947974
# 25253  41.794480310181626  -87.78661169891166
#
#                                                 location  \
# 0      {'type': 'Point', 'coordinates': [-87.71955488...
# 1      {'type': 'Point', 'coordinates': [-87.66807949...
# 2      {'type': 'Point', 'coordinates': [-87.79835876...
# 3      {'type': 'Point', 'coordinates': [-87.63088485...
# 4      {'type': 'Point', 'coordinates': [-87.80674170...
# ...                                                  ...
# 25249  {'type': 'Point', 'coordinates': [-87.70721421...
# 25250  {'type': 'Point', 'coordinates': [-87.64557103...
# 25251  {'type': 'Point', 'coordinates': [-87.70751585...
# 25252  {'type': 'Point', 'coordinates': [-87.75317109...
# 25253  {'type': 'Point', 'coordinates': [-87.78661169...
#
#                          geometry  index_right AREA_NUMBE           COMMUNITY  \
# 0      POINT (-87.71955 41.87154)         27.0         27  EAST GARFIELD PARK
# 1      POINT (-87.66808 41.88339)         28.0         28      NEAR WEST SIDE
# 2      POINT (-87.79836 41.99913)         35.0         10        NORWOOD PARK
# 3      POINT (-87.63088 41.88787)         36.0          8     NEAR NORTH SIDE
# 4      POINT (-87.80674 42.01519)         76.0          9         EDISON PARK
# ...                           ...          ...        ...                 ...
# 25249  POINT (-87.70721 41.87266)         27.0         27  EAST GARFIELD PARK
# 25250  POINT (-87.64557 41.75073)         69.0         71      AUBURN GRESHAM
# 25251  POINT (-87.70752 41.87265)         27.0         27  EAST GARFIELD PARK
# 25252  POINT (-87.75317 41.95251)         14.0         15        PORTAGE PARK
# 25253  POINT (-87.78661 41.79448)         54.0         56      GARFIELD RIDGE
#
#           SHAPE_AREA
# 0      53883220.8462
# 1      158492466.554
# 2       121959105.47
# 3      76675895.9728
# 4      31636313.7864
# ...              ...
# 25249  53883220.8462
# 25250  105065353.602
# 25251  53883220.8462
# 25252  110196097.139
# 25253  117890778.429
#
# [75254 rows x 12 columns]

# %%
allhomes_df.head()
# Out:
#         id                     permit_type community_area ward  \
# 0  3316806  PERMIT - RENOVATION/ALTERATION             27   24
# 1  3362770  PERMIT - RENOVATION/ALTERATION             28   27
# 2  3368303  PERMIT - RENOVATION/ALTERATION             10   41
# 3  3373499  PERMIT - RENOVATION/ALTERATION              8   42
# 4  3378148  PERMIT - RENOVATION/ALTERATION              9   41
#
#             latitude           longitude  \
# 0  41.87153852754136  -87.71955488514301
# 1  41.88338943530201  -87.66807949279023
# 2  41.99913120190079   -87.7983587609477
# 3  41.88787484815479  -87.63088485124779
# 4  42.01519122083687    -87.806741706282
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [-87.71955488...
# 1  {'type': 'Point', 'coordinates': [-87.66807949...
# 2  {'type': 'Point', 'coordinates': [-87.79835876...
# 3  {'type': 'Point', 'coordinates': [-87.63088485...
# 4  {'type': 'Point', 'coordinates': [-87.80674170...

# %%
energy_df.head()
# Out:
#   data_year      id reporting_status                    address zip_code  \
# 0      2021  101671    Not Submitted     6101 6115 N SEELEY AVE    60659
# 1      2021  101826    Not Submitted     8136 8142 S DREXEL AVE    60619
# 2      2021  102323    Not Submitted  3515 3525 W FRANKLIN BLVD    60624
# 3      2022  256888   Submitted Data         318 N CARPENTER ST    60607
# 4      2021  104374    Not Submitted        6000  N SHERIDAN RD    60660
#
#   chicago_energy_rating exempt_from_chicago_energy_rating community_area  \
# 0                     0                             False     WEST RIDGE
# 1                     0                             False        CHATHAM
# 2                     0                             False  HUMBOLDT PARK
# 3                     4                             False            NaN
# 4                     0                             False      EDGEWATER
#
#   gross_floor_area_buildings_sq_ft           latitude  ...  \
# 0                            65250        41.99046172  ...
# 1                            66888        41.74401302  ...
# 2                            93000         41.8808242  ...
# 3                           104849  41.88736471232649  ...
# 4                            55686        41.99090057  ...
#
#   district_steam_use_kbtu district_chilled_water_use_kbtu site_eui_kbtu_sq_ft  \
# 0                     NaN                             NaN                 NaN
# 1                     NaN                             NaN                 NaN
# 2                     NaN                             NaN                 NaN
# 3                       0                               0                32.4
# 4                     NaN                             NaN                 NaN
#
#   source_eui_kbtu_sq_ft weather_normalized_site_eui_kbtu_sq_ft  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                  61.9                                   32.8
# 4                   NaN                                    NaN
#
#   weather_normalized_source_eui_kbtu_sq_ft  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                     61.4
# 4                                      NaN
#
#   total_ghg_emissions_metric_tons_co2e ghg_intensity_kg_co2e_sq_ft  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                311.5                           3
# 4                                  NaN                         NaN
#
#   water_use_kgal all_other_fuel_use_kbtu
# 0            NaN                     NaN
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
#
# [5 rows x 35 columns]

# %%
energy_df_clean['latitude'] = energy_df_clean['latitude'].astype(float)
energy_df_clean['longitude'] = energy_df_clean['longitude'].astype(float)

allhomes_df.loc[:, 'latitude'] = allhomes_df['latitude'].astype(float)
allhomes_df.loc[:, 'longitude'] = allhomes_df['longitude'].astype(float)
allhomes_df = allhomes_df.copy()

merged = energy_df_clean.merge(allhomes_df, on=['latitude', 'longitude'])

# %%
merged.shape, merged.columns
# Out:
# ((7604, 40),
#  Index(['data_year', 'id_x', 'reporting_status', 'address', 'zip_code',
#         'chicago_energy_rating', 'exempt_from_chicago_energy_rating',
#         'community_area_x', 'gross_floor_area_buildings_sq_ft', 'latitude',
#         'longitude', 'location_x', 'row_id', ':@computed_region_43wa_7qmu',
#         ':@computed_region_vrxf_vc4k', ':@computed_region_6mkv_f3dw',
#         ':@computed_region_bdys_3d7i', ':@computed_region_awaf_s7ux',
#         'property_name', 'primary_property_type', 'year_built', 'of_buildings',
#         'energy_star_score', 'electricity_use_kbtu', 'natural_gas_use_kbtu',
#         'district_steam_use_kbtu', 'district_chilled_water_use_kbtu',
#         'site_eui_kbtu_sq_ft', 'source_eui_kbtu_sq_ft',
#         'weather_normalized_site_eui_kbtu_sq_ft',
#         'weather_normalized_source_eui_kbtu_sq_ft',
#         'total_ghg_emissions_metric_tons_co2e', 'ghg_intensity_kg_co2e_sq_ft',
#         'water_use_kgal', 'all_other_fuel_use_kbtu', 'id_y', 'permit_type',
#         'community_area_y', 'ward', 'location_y'],
#        dtype='object'))

# %%
# Round to 4 or 5 decimal places (approx ~11m or ~1m accuracy)
energy_df_clean['lat_round'] = energy_df_clean['latitude'].round(5)
energy_df_clean['lon_round'] = energy_df_clean['longitude'].round(5)

allhomes_df['lat_round'] = allhomes_df['latitude'].round(5)
allhomes_df['lon_round'] = allhomes_df['longitude'].round(5)

merged = energy_df_clean.merge(allhomes_df, on=['lat_round', 'lon_round'])
df = merged[['data_year', 'id_x',  'zip_code',  'chicago_energy_rating', 'latitude_x', 'longitude_x', 'location_x', 'property_name', 'year_built', 'community_area_y', 'permit_type', 'ward']]
df.columns = ['data_year', 'id',  'zip_code',  'chicago_energy_rating', 'latitude', 'longitude', 'location', 'property_name', 'year_built', 'community_area', 'permit_type', 'ward']
display(df)
# Out:
#        data_year      id zip_code chicago_energy_rating   latitude  longitude  \
# 0           2022  256888    60607                     4  41.887365 -87.653505
# 1           2022  256888    60607                     4  41.887365 -87.653505
# 2           2022  256888    60607                     4  41.887365 -87.653505
# 3           2022  256888    60607                     4  41.887365 -87.653505
# 4           2022  256888    60607                     4  41.887365 -87.653505
# ...          ...     ...      ...                   ...        ...        ...
# 16179       2023  256671    60608                     4  41.789841 -87.622490
# 16180       2023  251300    60614                     2  41.908254 -87.639863
# 16181       2023  106052    60660                     4  41.773447 -87.568490
# 16182       2023  106052    60660                     4  41.773447 -87.568490
# 16183       2023  240953    60654                     2  41.842506 -87.695297
#
#                                                 location  \
# 0      {'latitude': '41.88736471232649', 'longitude':...
# 1      {'latitude': '41.88736471232649', 'longitude':...
# 2      {'latitude': '41.88736471232649', 'longitude':...
# 3      {'latitude': '41.88736471232649', 'longitude':...
# 4      {'latitude': '41.88736471232649', 'longitude':...
# ...                                                  ...
# 16179  {'latitude': '41.789841', 'longitude': '-87.62...
# 16180  {'latitude': '41.908254', 'longitude': '-87.63...
# 16181  {'latitude': '41.773447', 'longitude': '-87.56...
# 16182  {'latitude': '41.773447', 'longitude': '-87.56...
# 16183  {'latitude': '41.842506', 'longitude': '-87.69...
#
#                                            property_name year_built  \
# 0                                                    NaN       2019
# 1                                                    NaN       2019
# 2                                                    NaN       2019
# 3                                                    NaN       2019
# 4                                                    NaN       2019
# ...                                                  ...        ...
# 16179                                     Chantico Lofts       2007
# 16180     2020 Lincoln Park West Condominium Association       1972
# 16181                              6214 N. Winthrop, LLC       1969
# 16182                              6214 N. Winthrop, LLC       1969
# 16183  (IL247) - River Place on the Park Condo (700 N...       2006
#
#       community_area                     permit_type ward
# 0                 28  PERMIT - RENOVATION/ALTERATION   27
# 1                 28  PERMIT - RENOVATION/ALTERATION   27
# 2                 28       PERMIT - NEW CONSTRUCTION   27
# 3                 28       PERMIT - NEW CONSTRUCTION   27
# 4                 28       PERMIT - NEW CONSTRUCTION   27
# ...              ...                             ...  ...
# 16179             40  PERMIT - RENOVATION/ALTERATION   20
# 16180              8  PERMIT - RENOVATION/ALTERATION   27
# 16181             43  PERMIT - RENOVATION/ALTERATION    5
# 16182             43  PERMIT - RENOVATION/ALTERATION    5
# 16183            NaN  PERMIT - RENOVATION/ALTERATION  NaN
#
# [16184 rows x 12 columns]
